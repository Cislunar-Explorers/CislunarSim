# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("../../runs/v4.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 60 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   286 non-null    int64
#  1   true_state.state.fill_frac                   286 non-null    float64
#  2   true_state.state.h_x                         286 non-null    float64
#  3   true_state.state.h_y                         286 non-null    float64
#  4   true_state.state.h_z                         286 non-null    float64
#  5   true_state.state.quat_v1                     286 non-null    float64
#  6   true_state.state.quat_v2                     286 non-null    float64
#  7   true_state.state.quat_v3                     286 non-null    float64
#  8   true_state.state.quat_r                      286 non-null    float64
#  9   true_state.state.vel_x                       286 non-null    float64
#  10  true_state.state.vel_y                       286 non-null    float64
#  11  true_state.state.vel_z                       286 non-null    float64
#  12  true_state.state.x                           286 non-null    float64
#  13  true_state.state.y                           286 non-null    float64
#  14  true_state.state.z                           286 non-null    float64
#  15  true_state.state.force_propulsion_thrusters  286 non-null    float64
#  16  true_state.state.fuel_mass                   286 non-null    float64
#  17  true_state.state.chamber_temp                286 non-null    float64
#  18  true_state.state.force_earth                 286 non-null    float64
#  19  true_state.state.force_moon                  286 non-null    float64
#  20  true_state.state.propulsion_on               286 non-null    float64
#  21  true_state.state.solenoid_actuation_on       286 non-null    float64
#  22  true_state.time                              286 non-null    float64
#  23  true_state.derived_state.I                   286 non-null    object
#  24  true_state.derived_state.ang_vel             286 non-null    object
#  25  true_state.derived_state.kane_c              286 non-null    float64
#  26  true_state.derived_state.r_co                286 non-null    object
#  27  true_state.derived_state.r_mo                286 non-null    object
#  28  true_state.derived_state.r_so                286 non-null    object
#  29  true_state.derived_state.r_eo                286 non-null    object
#  30  true_state.derived_state.r_mc                286 non-null    object
#  31  true_state.derived_state.r_sc                286 non-null    object
#  32  true_state.derived_state.r_ec                286 non-null    object
#  33  true_state.derived_state.attitude_vector     286 non-null    object
#  34  true_state.derived_state.azimuth             286 non-null    float64
#  35  true_state.derived_state.elevation           286 non-null    float64
#  36  observed_state.fill_frac                     286 non-null    float64
#  37  observed_state.h_x                           286 non-null    float64
#  38  observed_state.h_y                           286 non-null    float64
#  39  observed_state.h_z                           286 non-null    float64
#  40  observed_state.quat_v1                       286 non-null    float64
#  41  observed_state.quat_v2                       286 non-null    float64
#  42  observed_state.quat_v3                       286 non-null    float64
#  43  observed_state.quat_r                        286 non-null    float64
#  44  observed_state.vel_x                         286 non-null    float64
#  45  observed_state.vel_y                         286 non-null    float64
#  46  observed_state.vel_z                         286 non-null    float64
#  47  observed_state.x                             286 non-null    float64
#  48  observed_state.y                             286 non-null    float64
#  49  observed_state.z                             286 non-null    float64
#  50  observed_state.force_propulsion_thrusters    286 non-null    float64
#  51  observed_state.fuel_mass                     286 non-null    float64
#  52  observed_state.chamber_temp                  286 non-null    float64
#  53  observed_state.force_earth                   286 non-null    float64
#  54  observed_state.force_moon                    286 non-null    float64
#  55  observed_state.propulsion_on                 286 non-null    bool
#  56  observed_state.solenoid_actuation_on         286 non-null    bool
#  57  observed_state.ang_vel_x                     286 non-null    float64
#  58  observed_state.ang_vel_y                     286 non-null    float64
#  59  observed_state.ang_vel_z                     286 non-null    float64
# dtypes: bool(2), float64(47), int64(1), object(10)
# memory usage: 130.3+ KB

# %%
df = data[["true_state.time", "true_state.state.quat_r", "true_state.state.quat_v1","true_state.state.quat_v2", "true_state.state.quat_v3"]]
melted = pd.melt(df, id_vars=['true_state.time'], var_name="quat")
sns.lineplot(data=melted, x='true_state.time', y="value", hue="quat")
# Out:
# <Axes: xlabel='true_state.time', ylabel='value'>

# %%
momentum_df = data[["true_state.time", "true_state.state.h_x", "true_state.state.h_y","true_state.state.h_z"]]
def magnitude(x, y, z):
    return (x**2 + y**2 + z**2)

# apply the magnitude function to each row of the dataframe to create a new column
momentum_df['magnitude'] = momentum_df.apply(lambda row: magnitude(row['true_state.state.h_x'], row['true_state.state.h_y'], row['true_state.state.h_z']), axis=1)

melted = pd.melt(momentum_df, id_vars=['true_state.time'], var_name="component")
sns.lineplot(data=melted, x='true_state.time', y="value", hue="component")
# Out:
# /tmp/ipykernel_13245/1295394976.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   momentum_df['magnitude'] = momentum_df.apply(lambda row: magnitude(row['true_state.state.h_x'], row['true_state.state.h_y'], row['true_state.state.h_z']), axis=1)
# <Axes: xlabel='true_state.time', ylabel='value'>

# %%
# code directly ripped from ChatGPT, thx:

import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets

# Define the number of time steps and the maximum length of the vectors
num_steps = len(momentum_df)
max_length = np.sqrt(momentum_df['true_state.state.h_x']**2 + momentum_df['true_state.state.h_y']**2 + momentum_df['true_state.state.h_z']**2).max()

# Create figure and axis objects
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.set_xlim([-3,3])
ax.set_ylim([-3,3])
ax.set_zlim([-3,3])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Plot the initial data
q = ax.quiver(0,0,0,momentum_df['true_state.state.h_x'], momentum_df['true_state.state.h_y'], momentum_df['true_state.state.h_z'])

# Define function to update plot when the slider is moved
def update_plot(step):
    q.set_segments(momentum_df.loc[step, 'true_state.state.h_x'], momentum_df.loc[step, 'true_state.state.h_y'], momentum_df.loc[step, true_state.state.h_z'])
    ax.set_title(f'Time Step: {step}')
    fig.canvas.draw_idle()


# Create a slider widget to interactively select the time step
time_step_slider = widgets.IntSlider(
    value=0, min=0, max=num_steps-1, step=1,
    description='Time Step:', orientation='horizontal')

# Connect the slider to the update function
widgets.interactive(update_plot, step=time_step_slider)

# Show the plot
plt.show()

# still doesn't work on my machine. sadge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'true_state.state.h_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/ipywidgets/widgets/interaction.py:240, in interactive.update(self, *args)
#     238     value = widget.get_interact_value()
#     239     self.kwargs[widget._kwarg] = value
# --> 240 self.result = self.f(**self.kwargs)
#     241 show_inline_matplotlib_plots()
#     242 if self.auto_display and self.result is not None:
#
# Cell In[10], line 28, in update_plot(step)
#      26 def update_plot(step):
#      27     q.set
# ---> 28     q.set_segments(df.loc[step, 'true_state.state.h_x'], df.loc[step, 'v'], df.loc[step, 'w'])
#      29     ax.set_title(f'Time Step: {step}')
#      30     fig.canvas.draw_idle()
#
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/core/frame.py:3879, in DataFrame._get_value(self, index, col, takeable)
#    3876     series = self._ixs(col, axis=1)
#    3877     return series._values[index]
# -> 3879 series = self._get_item_cache(col)
#    3880 engine = self.index._engine
#    3882 if not isinstance(self.index, MultiIndex):
#    3883     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3884     #  results if our categories are integers that dont match our codes
#    3885     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/core/frame.py:4264, in DataFrame._get_item_cache(self, item)
#    4259 res = cache.get(item)
#    4260 if res is None:
#    4261     # All places that call _get_item_cache have unique columns,
#    4262     #  pending resolution of GH#33047
# -> 4264     loc = self.columns.get_loc(item)
#    4265     res = self._ixs(loc, axis=1)
#    4267     cache[item] = res
#
# File ~/dev/dataviz/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'true_state.state.h_x'
